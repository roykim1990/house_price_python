# %%
import pandas
import json
from modelop.schema.infer import infer_schema, set_monitoring_parameters

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# both baseline and sample should have the same schema
df = pandas.read_json('df_baseline_scored.json', orient='records', lines=True)

# %%
df_schema = infer_schema(data=df, schema_name='input_schema.avsc')

# %%
pandas.DataFrame(df_schema['fields'])
# Out:
#                     name     type    dataClass        role  protectedClass  \
# 0                     Id      int    numerical  identifier           False
# 1             prediction    float    numerical       score           False
# 2              SalePrice      int    numerical   predictor           False
# 3   eOverallQual_TotalSF      int    numerical   predictor           False
# 4            OverallQual      int    numerical   predictor           False
# 5               eTotalSF      int    numerical   predictor           False
# 6              GrLivArea      int    numerical   predictor           False
# 7              ExterQual      int    numerical   predictor           False
# 8            KitchenQual      int    numerical   predictor           False
# 9             GarageCars      int    numerical   predictor           False
# 10       eTotalBathrooms    float    numerical   predictor           False
# ...

# %%
with open('input_schema.avsc', 'w') as fp:
    json.dump(df_schema, fp, indent=2)

# %% [markdown]
# As `SalePrice` is our target variable and the schema generator did not correctly specifiy it as such, we'll have to manually edit that portion of the schema.

# %%
monitoring_parameters = set_monitoring_parameters(df_schema)
monitoring_parameters
# Out:
# {'predictors': ['eHasGarage',
#   'eHasRemodeling',
#   'eHasFireplace',
#   'eHasBsmt',
#   'eOverallQual_TotalSF',
#   'OverallQual',
#   'eTotalSF',
#   'GrLivArea',
#   'ExterQual',
#   'KitchenQual',
#   'GarageCars',
#   'eTotalBathrooms',
#   'BsmtQual',
#   'GarageArea',
#   'TotalBsmtSF',
#   'GarageFinish',
#   'YearBuilt',
#   'TotRmsAbvGrd',
#   'FireplaceQu',
#   'MasVnrArea'],
#  'categorical_columns': ['eHasGarage',
#   'eHasRemodeling',
#   'eHasFireplace',
#   'eHasBsmt'],
#  'numerical_columns': ['eOverallQual_TotalSF',
#   'OverallQual',
#   'eTotalSF',
#   'GrLivArea',
#   'ExterQual',
#   'KitchenQual',
#   'GarageCars',
#   'eTotalBathrooms',
#   'BsmtQual',
#   'GarageArea',
#   'TotalBsmtSF',
#   'GarageFinish',
#   'YearBuilt',
#   'TotRmsAbvGrd',
#   'FireplaceQu',
#   'MasVnrArea'],
#  'identifier_columns': ['Id'],
#  'weight_column': None,
#  'score_column': 'prediction',
#  'label_column': 'ground_truth',
#  'label_type': 'numerical',
# ...
